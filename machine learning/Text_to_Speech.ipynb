# %% [markdown]
# ### Text to Speech conversion using GTTS

# %%
#!pip install gtts
# Out:
# ...
#
#   Attempting uninstall: click
#
#     Found existing installation: click 8.2.1
#
#     Uninstalling click-8.2.1:
#
#       Successfully uninstalled click-8.2.1
#
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    ---------------------------------------- 0/2 [click]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
#    -------------------- ------------------- 1/2 [gtts]
#    ---------------------------------------- 2/2 [gtts]
#
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('''Hello everyone, welcome to this Data Science learning program. This program is designed 
to provide practical knowledge and hands-on experience in data science, machine learning, and Python. Our sessions 
focus on building strong coding skills through real-world projects and industry-oriented examples. Whether you are 
a beginner or an experienced learner, this program will help you enhance your technical skills and grow in your 
career. Thank you. ''',lang='hi',tld='com')

text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay= False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Text to Speech conversion using pyttsx3
#
# #### Changing the gender using pyttsx3

# %%
#!pip install pyttsx3
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    -------------------------- ------------- 2/3 [pyttsx3]
#    ---------------------------------------- 3/3 [pyttsx3]
#
# ...

# %%
import pyttsx3
from IPython.display import Audio

text = ''' Hello everyone, welcome to this Data Science learning program. This program is designed to provide 
practical knowledge and hands-on experience in data science, machine learning, and Python. Our sessions focus 
on building strong coding skills through real-world projects and industry-oriented examples. Whether you are a 
beginner or an experienced learner, this program will help you enhance your technical skills and grow in your career.
 Thank you.'''

audio = pyttsx3.init()
audio.setProperty('rate', 150)
audio.setProperty('volume', 0.8)

# change the voices
voice = audio.getProperty('voices')

# 0 for male and 1 for female
audio.setProperty('voice', voice[0].id)      # for male voice   
#audio.setProperty('voice', voice[1].id)       # for female voice

# text-to speech conversion
audio.say(text)

# save the audio file
audio.save_to_file(text, 'test_male_Voice.mp3')
#audio.save_to_file(text, 'test_female_Voice.mp3')

audio.runAndWait()
