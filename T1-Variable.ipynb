# %%
Syntax:
Python
variable_name = value
# Out:
# 25

# %% [markdown]
# Example 1: Integer variable

# %%
age = 25
print(age)
# Out:
# 25

# %% [markdown]
# Example 2: String Variable

# %%
name = "Ali"
print(name)
# Out:
# Ali

# %% [markdown]
# Example 3: Float Variable

# %%
price = 11.09
print(price)
# Out:
# 11.09

# %% [markdown]
# Example 4: Boolen Variable

# %% [markdown]
# is_active = True
# print(is_active)

# %% [markdown]
# 1.storing and Printing a Value

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# 2.Using Variable in Expression

# %%
a = 5
b = 3
result = a + b
print(result)
# Out:
# 8

# %% [markdown]
# 3.Changing the Value of a Variable

# %%
score = 50
print(score)
# Out:
# 50

# %%
score = 100
print(score)
# Out:
# 100

# %% [markdown]
# 4.Concatenating String

# %%
first_name = "John"
last_name = "Doe"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# John Doe

# %% [markdown]
# #Assigning value to variable

# %%
length = 10
width = 5

# Calulating the area of a rectangle
area = length * width
print(area)
# Out:
# 50

# %% [markdown]
# notes: Variable can store any tupe of data,including numbers,string, dicitionaries,objects, etc.
