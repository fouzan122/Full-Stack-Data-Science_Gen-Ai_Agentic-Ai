# %% [markdown]
# # Number_operator_28th

# %%
3+5
# Out:
# 8

# %%
8-6
# Out:
# 2

# %% [markdown]
# # Store previous value '_'

# %%
2+4
# Out:
# 6

# %%
_
# Out:
# '{"dataframes": [], "user": "Lenovo"}'

# %%
a=2+4

# %%
a
# Out:
# 6

# %%
14/2  #float division
# Out:
# 7.0

# %%
14//2   #int division
# Out:
# 7

# %% [markdown]
#  # mas (mul,add,sub)

# %%
4+5-10*3    #mas (mul,add,sub)
# Out:
# -21

# %% [markdown]
# # BODMAS

# %%
4+(10-5)*2    #BODMAS
# Out:
# 14

# %% [markdown]
# # back,div,,mul,add,sub

# %%
4/(10-4)*3   #brack, div, mul,add, sub.
# Out:
# 2.0
